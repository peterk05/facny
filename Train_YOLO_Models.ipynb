# %% [markdown]
# <a href="https://colab.research.google.com/github/peterk05/facny/blob/main/Train_YOLO_Models.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Train YOLO Models in Google Colab
# **Author:** Evan Juras, [EJ Technology Consultants](https://ejtech.io)
#
# **Last updated:** January 3, 2025
#
# **GitHub:** [Train and Deploy YOLO Models](https://github.com/EdjeElectronics/Train-and-Deploy-YOLO-Models)
#
# # Introduction
#
# This notebook uses [Ultralytics](https://docs.ultralytics.com/) to train YOLO11, YOLOv8, or YOLOv5 object detection models with a custom dataset. At the end of this Colab, you'll have a custom YOLO model that you can run on your PC, phone, or edge device like the Raspberry Pi.
#
# <p align=center>
# <img src="https://s3.us-west-1.amazonaws.com/evanjuras.com/img/yolo-model-demo.gif" height="360"><br>
# <i>Custom YOLO candy detection model in action!</i>
# </p>
#
# I created a YouTube video that walks through this guide step by step. I recommend following along with the video while working through this notebook.
#
# <p align=center>
# <a href="https://youtu.be/r0RspiLG260" target="_blank"><img src="https://raw.githubusercontent.com/EdjeElectronics/Train-and-Deploy-YOLO-Models/refs/heads/main/doc/Train_YOLO_Thumbnail2.png" height="240"><br>
# <i>Click here to go to the video!</i></a>
# </p>
#
# **Important note: This notebook will be continuously updated to make sure it works with newer versions of Ultralytics and YOLO. If you see any differences between the YouTube video and this notebook, always follow the notebook!**
#
# ### Working in Colab
# Colab provides a virtual machine in your browser complete with a Linux OS, filesystem, Python environment, and best of all, a free GPU. We'll install PyTorch and Ultralytics in this environment and use it to train our model. Simply click the Play button on sections of code in this notebook to execute them on the virtual machine.
#
# ### Navigation
# To navigate this notebook, use the table of contents in the left sidebar to jump from section to section.

# %% [markdown]
# **Verify NVIDIA GPU Availability**
#
# Make sure you're using a GPU-equipped machine by going to "Runtime" -> "Change runtime type" in the top menu bar, and then selecting one of the GPU options in the Hardware accelerator section. Click Play on the following code block to verify that the NVIDIA GPU is present and ready for training.

# %%
# !nvidia-smi
# Out:
# Wed Dec 17 19:24:26 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   41C    P8             10W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %% [markdown]
# #1.&nbsp;Gather and Label Training Images

# %% [markdown]
# Before we start training, we need to gather and label images that will be used for training the object detection model. A good starting point for a proof-of-concept model is 200 images. The training images should have random objects in the image along with the desired objects, and should have a variety of backgrounds and lighting conditions.
#
# There are a couple options for gathering images:
#
#
# *   Build a custom dataset by taking your own pictures of the objects and labeling them (this typically results in the best performance)
# *   Find a pre-made dataset from sources like [Roboflow Universe](), [Kaggle](), or [Google Images V7]()
#
#
# If you want to build your own dataset, there are several tools available for labeling images. One good option is [Label Studio](https://labelstud.io/?utm_source=youtube&utm_medium=video&utm_campaign=edjeelectronics), a free and open-source labeling tool that has a simple workflow while providing capabilities for more advanced features. My YouTube video that walks through this notebook (link to be added soon) shows how to label images with Label Studio.
#
# <p align=center>
# <img src="https://raw.githubusercontent.com/EdjeElectronics/Train-and-Deploy-YOLO-Models/refs/heads/main/doc/label-studio-example.PNG" height="380"><br>
# <i>Example of a candy image labeled with Label Studio.</i>
# </p>
#
# If you used Label Studio to label and export the images, they'll be exported in a `project.zip` file that contains the following:
#
# - An `images` folder containing the images
# - A `labels` folder containing the labels in YOLO annotation format
# - A `classes.txt` labelmap file that contains all the classes
# - A `notes.json` file that contains info specific to Label Studio (this file can be ignored)
#
# If you obtained your dataset from another source (like Roboflow Universe) or used another tool to label your dataset, make sure the files are organized in the same folder structure.
#
# <p align=center>
# <img src="https://raw.githubusercontent.com/EdjeElectronics/Train-and-Deploy-YOLO-Models/refs/heads/main/doc/zipped-data-example.png" height=""><br>
# <i>Organize your data in the folders shown here. See my <a href="https://s3.us-west-1.amazonaws.com/evanjuras.com/resources/candy_data_06JAN25.zip">Candy Detection Dataset</a> for an example.</i>
# </p>
#
# Once you've got your dataset built, put into the file structure shown above, and zipped into `data.zip`, you're ready to move on to the next step.

# %% [markdown]
# # 2.&nbsp;Upload Image Dataset and Prepare Training Data

# %% [markdown]
# Next, we'll upload our dataset and prepare it for training with YOLO. We'll split the dataset into train and validation folders, and we'll automatically generate the configuration file for training the model.

# %% [markdown]
# ## 2.1 Upload images
#
# First, we need to upload the dataset to Colab. Here are a few options for moving the `data.zip` folder into this Colab instance.

# %% [markdown]
# **Option 1. Upload through Google Colab**
#
# Upload the `data.zip` file to the Google Colab instance by clicking the "Files" icon on the left hand side of the browser, and then the "Upload to session storage" icon. Select the zip folder to upload it.
#
# <p>
# <br>
# <img src="https://raw.githubusercontent.com/EdjeElectronics/Train-and-Deploy-YOLO-Models/refs/heads/main/doc/upload-colab-files.png" height="240">
# </p>

# %% [markdown]
# **Option 2. Copy from Google Drive**
#
# You can also upload your images to your personal Google Drive, mount the drive on this Colab session, and copy them over to the Colab filesystem. This option works well if you want to upload the images beforehand so you don't have to wait for them to upload each time you restart this Colab. If you have more than 50MB worth of images, I recommend using this option.
#
# First, upload the `data.zip` file to your Google Drive, and make note of the folder you uploaded them to. Replace `MyDrive/path/to/data.zip` with the path to your zip file. (For example, I uploaded the zip file to folder called "candy-dataset1", so I would use `MyDrive/candy-dataset1/data.zip` for the path). Then, run the following block of code to mount your Google Drive to this Colab session and copy the folder to this filesystem.

# %%
from google.colab import drive
drive.mount('/content/gdrive')

# !cp /content/gdrive/MyDrive/path/to/data.zip /content

# %% [markdown]
# **Option 3. Use my candy detection or coin detection dataset**
#
# If you just want to test the process on a pre-made dataset, you can use one of my datasets:
#
# *   [Candy image dataset](https://s3.us-west-1.amazonaws.com/evanjuras.com/resources/candy_data_14DEC24.zip), which contains 162 pictures of popular candies (Skittles, Snickers, etc)
# *   [Coin image dataset](https://s3.us-west-1.amazonaws.com/evanjuras.com/resources/YOLO_coin_data_12DEC30.zip), which contains 750 pictures of US coins (pennies, dimes, nickels, and quarters)
#
# Download one of the datasets by running the following code block. I'll use the candy detection dataset as the example for the rest of the notebook.

# %%
# To use my one of pre-made dataset instead of your own custom dataset, download it here (control which dataset is downloaded by commenting out either line)
# !wget -O /content/data.zip https://s3.us-west-1.amazonaws.com/evanjuras.com/resources/candy_data_06JAN25.zip # Candy dataset
#!wget -O /content/data.zip https://s3.us-west-1.amazonaws.com/evanjuras.com/resources/YOLO_coin_data_12DEC30.zip # Coin dataset

# %% [markdown]
# ## 2.2 Split images into train and validation folders

# %% [markdown]
# At this point, whether you used Option 1, 2, or 3, you should be able to click the folder icon on the left and see your `data.zip` file in the list of files. Next, we'll unzip `data.zip` and create some folders to hold the images. Run the following code block to unzip the data.

# %%
# Unzip images to a custom data folder
# !unzip -q /content/data.zip -d /content/custom_data
# 1. Go into the folder
# %cd /content/custom_data/data

# 2. Run the script pointing to the CURRENT folder (represented by '.')
# !python train_val_split.py --datapath="." --train_pct=0.9
# Out:
# replace /content/custom_data/data/classes.txt? [y]es, [n]o, [A]ll, [N]one, [r]ename: A
# /content/custom_data/data
# Number of image files: 1814
# Number of annotation files: 1749
# Images moving to train: 1632
# Images moving to validation: 182

# %% [markdown]
# Ultralytics requires a particular folder structure to store training data for models. Ultralytics requires a particular folder structure to store training data for models. The root folder is named “data”. Inside, there are two main folders:
#
# *   **Train**: These are the actual images used to train the model. In one epoch of training, every image in the train set is passed into the neural network. The training algorithm adjusts the network weights to fit the data in the images.
#
#
# *   **Validation**: These images are used to check the model's performance at the end of each training epoch.
#
# In each of these folders is a “images” folder and a “labels” folder, which hold the image files and annotation files respectively.

# %% [markdown]
# I wrote a Python script that will automatically create the required folder structure and randomly move 90% of dataset to the "train" folder and 10% to the "validation" folder. Run the following code block to download and execute the scrpt.

# %%
"""
# !wget -O /content/train_val_split.py https://raw.githubusercontent.com/EdjeElectronics/Train-and-Deploy-YOLO-Models/refs/heads/main/utils/train_val_split.py

# TO DO: Improve robustness of train_val_split.py script so it can handle nested data folders, etc
# !python train_val_split.py --datapath="/content/custom_data" --train_pct=0.9"""
# Out:
# '\n!wget -O /content/train_val_split.py https://raw.githubusercontent.com/EdjeElectronics/Train-and-Deploy-YOLO-Models/refs/heads/main/utils/train_val_split.py\n\n# TO DO: Improve robustness of train_val_split.py script so it can handle nested data folders, etc\n!python train_val_split.py --datapath="/content/custom_data" --train_pct=0.9'

# %% [markdown]
# # 3.&nbsp;Install Requirements (Ultralytics)
#
# Next, we'll install the Ultralytics library in this Google Colab instance. This Python library will be used to train the YOLO model.

# %%
# !pip install ultralytics
# Out:
# Collecting ultralytics
#   Downloading ultralytics-8.3.240-py3-none-any.whl.metadata (37 kB)
# Requirement already satisfied: numpy>=1.23.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (2.0.2)
# Requirement already satisfied: matplotlib>=3.3.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (3.10.0)
# Requirement already satisfied: opencv-python>=4.6.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (4.12.0.88)
# Requirement already satisfied: pillow>=7.1.2 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (11.3.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (6.0.3)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (2.32.4)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (1.16.3)
# Requirement already satisfied: torch>=1.8.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (2.9.0+cu126)
# Requirement already satisfied: torchvision>=0.9.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (0.24.0+cu126)
# Requirement already satisfied: psutil>=5.8.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (5.9.5)
# Requirement already satisfied: polars>=0.20.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (1.31.0)
# Collecting ultralytics-thop>=2.0.18 (from ultralytics)
#   Downloading ultralytics_thop-2.0.18-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (4.61.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (2025.11.12)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.20.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.3.20)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (1.11.1.6)
# Requirement already satisfied: triton==3.5.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.5.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.3)
# Downloading ultralytics-8.3.240-py3-none-any.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 32.0 MB/s eta 0:00:00
# Downloading ultralytics_thop-2.0.18-py3-none-any.whl (28 kB)
# Installing collected packages: ultralytics-thop, ultralytics
# Successfully installed ultralytics-8.3.240 ultralytics-thop-2.0.18

# %% [markdown]
# # 4.&nbsp;Configure Training

# %% [markdown]
# There's one last step before we can run training: we need to create the Ultralytics training configuration YAML file. This file specifies the location of your train and validation data, and it also defines the model's classes. An example configuration file model is available [here](https://github.com/ultralytics/ultralytics/blob/main/ultralytics/cfg/datasets/coco128.yaml).
#
# Run the code block below to automatically generate a `data.yaml` configuration file. Make sure you have a labelmap file located at `custom_data/classes.txt`. If you used Label Studio or one of my pre-made datasets, it should already be present. If you assembled the dataset another way, you may have to manually create the `classes.txt` file (see [here](https://github.com/EdjeElectronics/Train-and-Deploy-YOLO-Models/blob/main/doc/classes.txt) for an example of how it's formatted).

# %%
# Python function to automatically create data.yaml config file
# 1. Reads "classes.txt" file to get list of class names
# 2. Creates data dictionary with correct paths to folders, number of classes, and names of classes
# 3. Writes data in YAML format to data.yaml

import yaml
import os

def create_data_yaml(path_to_classes_txt, path_to_data_yaml):

  # Read class.txt to get class names
  if not os.path.exists(path_to_classes_txt):
    print(f'classes.txt file not found! Please create a classes.txt labelmap and move it to {path_to_classes_txt}')
    return
  with open(path_to_classes_txt, 'r') as f:
    classes = []
    for line in f.readlines():
      if len(line.strip()) == 0: continue
      classes.append(line.strip())
  number_of_classes = len(classes)

  # Create data dictionary
  data = {
      'path': '/content/data',
      'train': 'train/images',
      'val': 'validation/images',
      'nc': number_of_classes,
      'names': classes
  }

  # Write data to YAML file
  with open(path_to_data_yaml, 'w') as f:
    yaml.dump(data, f, sort_keys=False)
  print(f'Created config file at {path_to_data_yaml}')

  return

# Define path to classes.txt and run function
path_to_classes_txt = path_to_classes_txt = '/content/custom_data/data/classes.txt'

path_to_data_yaml = '/content/data.yaml'

create_data_yaml(path_to_classes_txt, path_to_data_yaml)

print('\nFile contents:\n')
# !cat /content/data.yaml
# Out:
# Created config file at /content/data.yaml
#
# File contents:
#
# path: /content/data
# train: train/images
# val: validation/images
# nc: 3
# names:
# - pigeon
# - crow
# - seagull

# %% [markdown]
# # 5.&nbsp;Train Model

# %% [markdown]
# ## 5.1 Training Parameters
# Now that the data is organized and the config file is created, we're ready to start training! First, there are a few important parameters to decide on. Visit my article on [Training YOLO Models Locally](https://www.ejtech.io/learn/train-yolo-models) to learn more about these parameters and how to choose them.
#
# **Model architecture & size (`model`):**
#
# There are several YOLO11 models sizes available to train, including `yolo11n.pt`, `yolo11s.pt`, `yolo11m.pt`, `yolo11l.pt`, and `yolo11xl.pt`. Larger models run slower but have higher accuracy, while smaller models run faster but have lower accuracy. I made a brief YouTube video that compares performance of different YOLO models on a Raspberry Pi 5 and a laptop with a RTX 4050 GPU, [check it out here to get a sense of their speed accuracy](https://youtu.be/_WKS4E9SmkA). If you aren't sure which model size to use, `yolo11s.pt` is a good starting point.
#
# You can also train YOLOv8 or YOLOv5 models by substituting `yolo11` for `yolov8` or `yolov5`.
#
#
# **Number of epochs (`epochs`)**
#
# In machine learning, one “epoch” is one single pass through the full training dataset. Setting the number of epochs dictates how long the model will train for. The best amount of epochs to use depends on the size of the dataset and the model architecture. If your dataset has less than 200 images, a good starting point is 60 epochs. If your dataset has more than 200 images, a good starting point is 40 epochs.
#
#
# **Resolution (`imgsz`)**
#
# Resolution has a large impact on the speed and accuracy of the model: a lower resolution model will have higher speed but less accuracy. YOLO models are typically trained and inferenced at a 640x640 resolution. However, if you want your model to run faster or know you will be working with low-resolution images, try using a lower resolution like 480x480.

# %% [markdown]
# ## 5.2 Run Training!

# %%
import yaml

# 1. Define the correct path to where your 'train' and 'validation' folders actually live
# Based on your previous steps, they are inside custom_data/data/data
correct_dataset_path = '/content/custom_data/data/data'

# 2. Define your class names (Make sure these match your classes.txt!)
# If you haven't fixed this yet, REPLACE with your actual class names
my_class_names = ['pigeon',"crow" , "seagull"]

# 3. Create the fixed data dictionary
data = {
    'path': correct_dataset_path,
    'train': 'train/images',
    'val': 'validation/images',
    'nc': len(my_class_names),
    'names': my_class_names
}

# 4. Save it
with open('/content/data.yaml', 'w') as f:
    yaml.dump(data, f, sort_keys=False)

print(f"Fixed data.yaml! It now points to: {correct_dataset_path}")
print("You can run the training command again.")
# Out:
# Fixed data.yaml! It now points to: /content/custom_data/data/data
# You can run the training command again.

# %% [markdown]
# Run the following code block to begin training. If you want to use a different model, number of epochs, or resolution, change `model`, `epochs`, or `imgsz`.

# %%
# !yolo detect train data=/content/data.yaml model=yolo11n.pt epochs=6 imgsz=640
# Out:
# Ultralytics 8.3.240 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# engine/trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/content/data.yaml, degrees=0.0, deterministic=True, device=None, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=6, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolo11n.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=train16, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=None, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=/content/custom_data/data/runs/detect/train16, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Overriding model.yaml nc=80 with nc=3
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      6640  ultralytics.nn.modules.block.C3k2            [32, 64, 1, False, 0.25]
#   3                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#   4                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   5                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   6                  -1  1     87040  ultralytics.nn.modules.block.C3k2            [128, 128, 1, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1    249728  ultralytics.nn.modules.block.C2PSA           [256, 256, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1    111296  ultralytics.nn.modules.block.C3k2            [384, 128, 1, False]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1     32096  ultralytics.nn.modules.block.C3k2            [256, 64, 1, False]
#  17                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1     86720  ultralytics.nn.modules.block.C3k2            [192, 128, 1, False]
#  20                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1    378880  ultralytics.nn.modules.block.C3k2            [384, 256, 1, True]
#  23        [16, 19, 22]  1    431257  ultralytics.nn.modules.head.Detect           [3, [64, 128, 256]]
# YOLO11n summary: 181 layers, 2,590,425 parameters, 2,590,409 gradients, 6.4 GFLOPs
#
# Transferred 448/499 items from pretrained weights
# Freezing layer 'model.23.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1007.6±570.0 MB/s, size: 26.2 KB)
# train: Scanning /content/custom_data/data/data/train/labels.cache... 1575 images, 57 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 1632/1632 23.0Mit/s 0.0s
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Fast image access ✅ (ping: 0.0±0.1 ms, read: 730.6±368.8 MB/s, size: 37.2 KB)
# val: Scanning /content/custom_data/data/data/validation/labels.cache... 174 images, 8 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 182/182 1.7Mit/s 0.0s
# Plotting labels to /content/custom_data/data/runs/detect/train16/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.001429, momentum=0.9) with parameter groups 81 weight(decay=0.0), 88 weight(decay=0.0005), 87 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 2 dataloader workers
# Logging results to /content/custom_data/data/runs/detect/train16
# Starting training for 6 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
# ^C

# %%
import os

# Define the root folder where your data lives
root_folder = '/content/custom_data/data/data'

print(f"Searching for cache files in {root_folder}...")

found_any = False
# Walk through all folders
for root, dirs, files in os.walk(root_folder):
    for file in files:
        # If we find a file ending in .cache (like labels.cache)
        if file.endswith('.cache'):
            full_path = os.path.join(root, file)
            try:
                os.remove(full_path) # DELETE IT
                print(f"🗑️ Deleted cache file: {full_path}")
                found_any = True
            except Exception as e:
                print(f"Error deleting {full_path}: {e}")

if not found_any:
    print("No cache files found. (That's okay too!)")
else:
    print("All cache files deleted. You can train now.")
# Out:
# Searching for cache files in /content/custom_data/data/data...
# 🗑️ Deleted cache file: /content/custom_data/data/data/validation/labels.cache
# 🗑️ Deleted cache file: /content/custom_data/data/data/train/labels.cache
# All cache files deleted. You can train now.

# %% [markdown]
# The training algorithm will parse the images in the training and validation directories and then start training the model. At the end of each training epoch, the program runs the model on the validation dataset and reports the resulting mAP, precision, and recall. As training continues, the mAP should generally increase with each epoch. Training will end once it goes through the number of epochs specified by `epochs`.
#
# > **NOTE:** Make sure to allow training to run to completion, because an optimizer runs at the end of training that strips out unneeded layers from the model.
#
# The best trained model weights will be saved in `content/runs/detect/train/weights/best.pt`. Additional information about training is saved in the `content/runs/detect/train` folder, including a `results.png` file that shows how loss, precision, recall, and mAP progressed over each epoch.

# %%
# !yolo detect train data=/content/data.yaml model=yolo11n.pt epochs=6 imgsz=640 batch=8 name=final_training_v1
# Out:
# Ultralytics 8.3.240 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# engine/trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=8, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/content/data.yaml, degrees=0.0, deterministic=True, device=None, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=6, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolo11n.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=final_training_v13, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=None, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=/content/custom_data/data/runs/detect/final_training_v13, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Overriding model.yaml nc=80 with nc=3
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      6640  ultralytics.nn.modules.block.C3k2            [32, 64, 1, False, 0.25]
#   3                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#   4                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   5                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   6                  -1  1     87040  ultralytics.nn.modules.block.C3k2            [128, 128, 1, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1    249728  ultralytics.nn.modules.block.C2PSA           [256, 256, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1    111296  ultralytics.nn.modules.block.C3k2            [384, 128, 1, False]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1     32096  ultralytics.nn.modules.block.C3k2            [256, 64, 1, False]
#  17                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1     86720  ultralytics.nn.modules.block.C3k2            [192, 128, 1, False]
#  20                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1    378880  ultralytics.nn.modules.block.C3k2            [384, 256, 1, True]
#  23        [16, 19, 22]  1    431257  ultralytics.nn.modules.head.Detect           [3, [64, 128, 256]]
# YOLO11n summary: 181 layers, 2,590,425 parameters, 2,590,409 gradients, 6.4 GFLOPs
#
# Transferred 448/499 items from pretrained weights
# Freezing layer 'model.23.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1189.0±853.9 MB/s, size: 26.2 KB)
# train: Scanning /content/custom_data/data/data/train/labels... 1575 images, 57 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 1632/1632 2.5Kit/s 0.7s
# train: New cache created: /content/custom_data/data/data/train/labels.cache
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 735.9±320.7 MB/s, size: 37.2 KB)
# val: Scanning /content/custom_data/data/data/validation/labels.cache... 174 images, 8 backgrounds, 144 corrupt: 100% ━━━━━━━━━━━━ 182/182 81.3Kit/s 0.0s
# val: /content/custom_data/data/data/validation/images/0ca47bad-sea77.jpg: ignoring corrupt image/label: Label class 2 exceeds dataset class count 1. Possible class labels are 0-0
# val: /content/custom_data/data/data/validation/images/4fe30641-sea76.jpg: ignoring corrupt image/label: Label class 2 exceeds dataset class count 1. Possible class labels are 0-0
# val: /content/custom_data/data/data/validation/images/5502ed5f-sea38.jpg: ignoring corrupt image/label: Label class 2 exceeds dataset class count 1. Possible class labels are 0-0
# val: /content/custom_data/data/data/validation/images/69164659-sea31.jpg: ignoring corrupt image/label: Label class 2 exceeds dataset class count 1. Possible class labels are 0-0
# val: /content/custom_data/data/data/validation/images/6f76fe22-sea91.jpg: ignoring corrupt image/label: Label class 2 exceeds dataset class count 1. Possible class labels are 0-0
# val: /content/custom_data/data/data/validation/images/93c5ce56-sea67.jpg: ignoring corrupt image/label: Label class 2 exceeds dataset class count 1. Possible class labels are 0-0
# val: /content/custom_data/data/data/validation/images/a0d641e1-sea66.jpg: ignoring corrupt image/label: Label class 2 exceeds dataset class count 1. Possible class labels are 0-0
# val: /content/custom_data/data/data/validation/images/a683b565-sea92.jpg: ignoring corrupt image/label: Label class 2 exceeds dataset class count 1. Possible class labels are 0-0
# val: /content/custom_data/data/data/validation/images/b59da93c-sea55.jpg: ignoring corrupt image/label: Label class 2 exceeds dataset class count 1. Possible class labels are 0-0
# val: /content/custom_data/data/data/validation/images/c92a38b9-sea73.jpg: ignoring corrupt image/label: Label class 2 exceeds dataset class count 1. Possible class labels are 0-0
# val: /content/custom_data/data/data/validation/images/crow-102-_jpg.rf.a4dd867d7ea746dae05b1312a914ec63.jpg: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: /content/custom_data/data/data/validation/images/crow-11-_jpg.rf.64fe26e400227822e57994fdb2632e45.jpg: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: /content/custom_data/data/data/validation/images/crow-121-_jpg.rf.2a89882fbcab8b30494872a9c3cda309.jpg: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: /content/custom_data/data/data/validation/images/crow-127-_jpg.rf.580bdf3c4186d20ddd9bbad7a2d57812.jpg: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: /content/custom_data/data/data/validation/images/crow-130-_jpg.rf.3c67814d29d7f2e76b16508724ab4b91.jpg: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: /content/custom_data/data/data/validation/images/crow-130-_jpg.rf.43167184d238a69d39d71eb10caf104c.jpg: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: /content/custom_data/data/data/validation/images/crow-135-_jpg.rf.25acb9b84d9f8c6160f1e67413acb46a.jpg: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: /content/custom_data/data/data/validation/images/crow-138-_jpg.rf.47a1a750cc4a5ceb1965e983dda32b0c.jpg: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: /content/custom_data/data/data/validation/images/crow-14-_jpg.rf.10097a287a9b15c1ed1bce19af94e677.jpg: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: /content/custom_data/data/data/validation/images/crow-143-_jpg.rf.ed445b6668b3403e00e030a051a9520c.jpg: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: /content/custom_data/data/data/validation/images/crow-146-_jpg.rf.85839fdd2f9c4822a4117be35930253b.jpg: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: /content/custom_data/data/data/validation/images/crow-162-_jpg.rf.6e93669ffc04ff3c57813d8ebcd1f4bf.jpg: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: /content/custom_data/data/data/validation/images/crow-165-_jpg.rf.a5c9996e4fa4239e0f8a908fc41bb952.jpg: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: /content/custom_data/data/data/validation/images/crow-168-_jpg.rf.0c37905b998c40d989aff92fd140a70d.jpg: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: /content/custom_data/data/data/validation/images/crow-176-_jpg.rf.e971c7a93fcc13fb4aee4bd014bad091.jpg: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: /content/custom_data/data/data/validation/images/crow-177-_jpg.rf.0958cc1fe3130ede05282d8281a1346e.jpg: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: /content/custom_data/data/data/validation/images/crow-178-_jpg.rf.f4ca6962ca6733243fefe1139e88ff00.jpg: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: /content/custom_data/data/data/validation/images/crow-179-_jpg.rf.84c83d46accf185e107259b8dccae412.jpg: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: /content/custom_data/data/data/validation/images/crow-188-_jpg.rf.369d1a2ff90336b7e81df0b6980a13bb.jpg: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: /content/custom_data/data/data/validation/images/crow-197-_jpg.rf.1e54553f0e73d9ad51ad85079e62990f.jpg: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: /content/custom_data/data/data/validation/images/crow-206-_jpg.rf.9eaad4982f5cb537c9693decc94fc1d1.jpg: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: /content/custom_data/data/data/validation/images/crow-212-_jpg.rf.4d35d420007edea2e931c58e5d86cedc.jpg: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: /content/custom_data/data/data/validation/images/crow-213-_jpg.rf.bd071f9b292e17dc00e0d575c05d6b30.jpg: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: /content/custom_data/data/data/validation/images/crow-217-_jpg.rf.74c8614c849d418fae4dd2a839dfe14e.jpg: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: /content/custom_data/data/data/validation/images/crow-219-_jpg.rf.e29eda403079e6dd1db9a3f75eb182ed.jpg: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: /content/custom_data/data/data/validation/images/crow-22-_jpg.rf.929a82023fe2beef7267f52c80bb6ada.jpg: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: /content/custom_data/data/data/validation/images/crow-226-_jpg.rf.f4e8e0014ffd6669142e643f5dce93e1.jpg: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: /content/custom_data/data/data/validation/images/crow-232-_jpg.rf.400bc8d293cbc441ca6ea7e701c7b3ff.jpg: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: /content/custom_data/data/data/validation/images/crow-233-_jpg.rf.2344854cda74a73fc43ca1a46b97b232.jpg: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: /content/custom_data/data/data/validation/images/crow-234-_jpg.rf.6b5fe9acef6acf5e4b5af9cbea7c68fa.jpg: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: /content/custom_data/data/data/validation/images/crow-235-_jpg.rf.b2cd40b7b0eeead4114f7c42645b4539.jpg: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: /content/custom_data/data/data/validation/images/crow-237-_jpg.rf.b858de8f5abfe85b1fd4e24478c02d46.jpg: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: /content/custom_data/data/data/validation/images/crow-238-_jpg.rf.4a6825bde22aa8fb66eccc1da7d9299c.jpg: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: /content/custom_data/data/data/validation/images/crow-249-_jpg.rf.f85ea49838261382d526b47de6525f03.jpg: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: /content/custom_data/data/data/validation/images/crow-252-_jpg.rf.5a3abd591e70929736da296c29878f36.jpg: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: /content/custom_data/data/data/validation/images/crow-255-_jpg.rf.53063a5720e8928ea8c0867dd50dde9c.jpg: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: /content/custom_data/data/data/validation/images/crow-260-_jpg.rf.9338c5a839f37c4939b7491884cafa16.jpg: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: /content/custom_data/data/data/validation/images/crow-269-_jpg.rf.569020036d5b6aba74d94798acd5f912.jpg: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: /content/custom_data/data/data/validation/images/crow-275-_jpg.rf.d3407bf81a3885d4d7e070ebb665d8a6.jpg: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: /content/custom_data/data/data/validation/images/crow-286-_jpg.rf.f4ba9020dddab34aee55dae0216b8242.jpg: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: /content/custom_data/data/data/validation/images/crow-289-_jpg.rf.9b09019d242765e6133e781fc89c2ef5.jpg: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: /content/custom_data/data/data/validation/images/crow-29-_jpg.rf.73126467d68591ee819df78780f374dc.jpg: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: /content/custom_data/data/data/validation/images/crow-298-_jpg.rf.26211ebf80ba12111ec5bffb221ea326.jpg: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: /content/custom_data/data/data/validation/images/crow-3-_jpg.rf.7604b3b84e0b2379b1408945e5c2d4b0.jpg: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: /content/custom_data/data/data/validation/images/crow-3-_jpg.rf.b9f633ca061f1d7308da08c0bf1e11d5.jpg: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: /content/custom_data/data/data/validation/images/crow-306-_jpg.rf.18f7338614644d7f71f65571edd070e7.jpg: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: /content/custom_data/data/data/validation/images/crow-308-_jpg.rf.3968ce6f48ba483296abf0cc53e7df20.jpg: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: /content/custom_data/data/data/validation/images/crow-310-_jpg.rf.ef8be79c19ac3025816b156e8d869617.jpg: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: /content/custom_data/data/data/validation/images/crow-316-_jpg.rf.93a117acaa9f39579aa622a3f1109199.jpg: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: /content/custom_data/data/data/validation/images/crow-32-_jpg.rf.195655a8995e8351b22504d4fcf13cf4.jpg: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: /content/custom_data/data/data/validation/images/crow-321-_jpg.rf.f7c85a781a4cbe68e3da3ba4b598bcb1.jpg: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: /content/custom_data/data/data/validation/images/crow-335-_jpg.rf.afb4b19239e9dcb29414b60807eccba1.jpg: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: /content/custom_data/data/data/validation/images/crow-343-_jpg.rf.ed7c1e73769847747362113ae427cd69.jpg: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: /content/custom_data/data/data/validation/images/crow-346-_jpg.rf.13ce979552a2dc5e6bfbf4ad4b820204.jpg: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: /content/custom_data/data/data/validation/images/crow-363-_jpg.rf.b48e0bbb7fab50afef9f0f474f3b83ef.jpg: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: /content/custom_data/data/data/validation/images/crow-369-_jpg.rf.8340bb55050ace34c5c38aa800cfc45d.jpg: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: /content/custom_data/data/data/validation/images/crow-374-_jpg.rf.6b6922f0c446694e8eef321986790758.jpg: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: /content/custom_data/data/data/validation/images/crow-376-_jpg.rf.56e000565202b9c8766bdc21d950c266.jpg: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: /content/custom_data/data/data/validation/images/crow-376-_jpg.rf.e834658519f1ac721cb0136344008d1a.jpg: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: /content/custom_data/data/data/validation/images/crow-38-_jpg.rf.7dfb165b0c5b606a6100f146821d8723.jpg: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: /content/custom_data/data/data/validation/images/crow-384-_jpg.rf.51dd5cadbded0fc50e9721294d7c3651.jpg: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: /content/custom_data/data/data/validation/images/crow-386-_jpg.rf.596745074706a4c625005b5b06b872c8.jpg: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: /content/custom_data/data/data/validation/images/crow-390-_jpg.rf.90b2973bd3e6227d903cd9a07dcaa532.jpg: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: /content/custom_data/data/data/validation/images/crow-397-_jpg.rf.36e7ed9d86287413fa7bc9ab3a20b533.jpg: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: /content/custom_data/data/data/validation/images/crow-404-_jpg.rf.dea7cb59b04e7482f95487fbf34d6489.jpg: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: /content/custom_data/data/data/validation/images/crow-409-_jpg.rf.7d3a1baaecbb705ae70a9a369501b8d5.jpg: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: /content/custom_data/data/data/validation/images/crow-41-_jpg.rf.b51c4fc04c3d195ca534453f6ec162a1.jpg: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: /content/custom_data/data/data/validation/images/crow-415-_jpg.rf.ce23f9d343a56c899ecba19489a07dae.jpg: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: /content/custom_data/data/data/validation/images/crow-418-_jpg.rf.a1c5b7ba9c6c4d5ebd52b98c5f1cf8a9.jpg: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: /content/custom_data/data/data/validation/images/crow-419-_jpg.rf.c66f10a7ac956f53c02e3bf570a5b7c9.jpg: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: /content/custom_data/data/data/validation/images/crow-425-_jpg.rf.7c7ff23ba967b0c3064ad742467e8feb.jpg: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: /content/custom_data/data/data/validation/images/crow-427-_jpg.rf.a651fc0b0321f96cec83c96c4c132204.jpg: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: /content/custom_data/data/data/validation/images/crow-431-_jpg.rf.a858a8dc3ca834b23341ccd10b95bcaf.jpg: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: /content/custom_data/data/data/validation/images/crow-438-_jpg.rf.93653e9d031af369c371e2d118fa90da.jpg: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: /content/custom_data/data/data/validation/images/crow-447-_jpg.rf.55e74f74dbb9c00223748da7acfaff64.jpg: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: /content/custom_data/data/data/validation/images/crow-448-_jpg.rf.b3b8b3ba185630a13b72076066902d7b.jpg: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: /content/custom_data/data/data/validation/images/crow-450-_jpg.rf.f6083f134f890e2df26f106128513eef.jpg: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: /content/custom_data/data/data/validation/images/crow-452-_jpg.rf.412d8ad72b4803d16d9caa65c5f3b70a.jpg: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: /content/custom_data/data/data/validation/images/crow-459-_jpg.rf.3eb7f5728cc3723dae5a379e04f76700.jpg: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: /content/custom_data/data/data/validation/images/crow-461-_jpg.rf.c5e341a2c505491b4c873ca4715347ae.jpg: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: /content/custom_data/data/data/validation/images/crow-48-_jpg.rf.5a2e69c8b9c5ba153e11f37f0c2efc22.jpg: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: /content/custom_data/data/data/validation/images/crow-489-_jpg.rf.8f9ad7d1261e25b7e3b0196ed2abc635.jpg: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: /content/custom_data/data/data/validation/images/crow-489-_jpg.rf.997598b76f4dc8e9a4c4d81a5eed1334.jpg: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: /content/custom_data/data/data/validation/images/crow-49-_jpg.rf.4aa1d1462cefe1557269bd92278ca8f9.jpg: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: /content/custom_data/data/data/validation/images/crow-491-_jpg.rf.cd9baa53c185f194ece60ab38b8cd2ff.jpg: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: /content/custom_data/data/data/validation/images/crow-501-_jpg.rf.2f458a9032841b789925a6df15317f80.jpg: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: /content/custom_data/data/data/validation/images/crow-51-_jpg.rf.43e914ab7928d2195ca15876b221f3c3.jpg: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: /content/custom_data/data/data/validation/images/crow-51-_jpg.rf.cdd86822b750f18f1b87b7ce2d172a2f.jpg: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: /content/custom_data/data/data/validation/images/crow-513-_jpg.rf.01936bc80f17b6a247f0c34f3f9384fe.jpg: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: /content/custom_data/data/data/validation/images/crow-518-_jpg.rf.7d0df08fd4cb00939992b57436d1aa2b.jpg: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: /content/custom_data/data/data/validation/images/crow-519-_jpg.rf.ed9338e2c4e59c52781ca027eb5eb2c7.jpg: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: /content/custom_data/data/data/validation/images/crow-522-_jpg.rf.a8e40c853dd5e6415050ce8b0be08940.jpg: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: /content/custom_data/data/data/validation/images/crow-529-_jpg.rf.bf2f0485d2ae095a61978d14e3bd7aca.jpg: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: /content/custom_data/data/data/validation/images/crow-533-_jpg.rf.0834d1356fbaa0778283dff634acd9a0.jpg: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: /content/custom_data/data/data/validation/images/crow-535-_jpg.rf.77cbef5cc73400eae63b198608c3f8fa.jpg: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: /content/custom_data/data/data/validation/images/crow-541-_jpg.rf.44c02836a866573513b8c53e3c91d216.jpg: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: /content/custom_data/data/data/validation/images/crow-55-_jpg.rf.0b5a9c2375540c8d5aef20c997406deb.jpg: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: /content/custom_data/data/data/validation/images/crow-555-_jpg.rf.3b1d726c499954673fe6e0805886e63b.jpg: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: /content/custom_data/data/data/validation/images/crow-563-_jpg.rf.9fb78874b11f82dbddc7b3f96496404c.jpg: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: /content/custom_data/data/data/validation/images/crow-566-_jpg.rf.1492f137676801ac59eeb69629b3753a.jpg: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: /content/custom_data/data/data/validation/images/crow-568-_jpg.rf.863f98c9e522fb0e4d6a6a4438623dae.jpg: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: /content/custom_data/data/data/validation/images/crow-569-_jpg.rf.8120f60d94daa8818a3a6c443334a58b.jpg: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: /content/custom_data/data/data/validation/images/crow-583-_jpg.rf.abe33f82210d939f72d6100f604c4c28.jpg: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: /content/custom_data/data/data/validation/images/crow-594-_jpg.rf.604d31511f567b06f3925d974425d7a3.jpg: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: /content/custom_data/data/data/validation/images/crow-6-_jpg.rf.80248fb358241268cb49d037484818dd.jpg: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: /content/custom_data/data/data/validation/images/crow-603-_jpg.rf.7c90210e4d2b5e890b81636d8caf434a.jpg: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: /content/custom_data/data/data/validation/images/crow-605-_jpg.rf.63ddd46e01eef006a0e3b4c5b0b3f712.jpg: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: /content/custom_data/data/data/validation/images/crow-609-_jpg.rf.43c85e029557eb1b143d82232bd1b387.jpg: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: /content/custom_data/data/data/validation/images/crow-612-_jpg.rf.1054d2422fdffeee15bd19a0a3ef957a.jpg: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: /content/custom_data/data/data/validation/images/crow-612-_jpg.rf.354fc14936adfe4074d9a7f1d885afc6.jpg: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: /content/custom_data/data/data/validation/images/crow-614-_jpg.rf.c5a9ee715c0e049d6ecfa961af3ac188.jpg: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: /content/custom_data/data/data/validation/images/crow-617-_jpg.rf.a8aef9c1c28fa6b158031554717a79e1.jpg: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: /content/custom_data/data/data/validation/images/crow-632-_jpg.rf.de0b4453de640f790103509bfe28c01d.jpg: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: /content/custom_data/data/data/validation/images/crow-637-_jpg.rf.bfdd01b8cab4bba492d824c6bef9393c.jpg: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: /content/custom_data/data/data/validation/images/crow-638-_jpg.rf.f75e350fe4ed4fa851248bcc9ebd463e.jpg: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: /content/custom_data/data/data/validation/images/crow-64-_jpg.rf.e9ce9349f7662d9b234de785a7a65263.jpg: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: /content/custom_data/data/data/validation/images/crow-642-_jpg.rf.ea043e21db0f4419a5b3999911bcb317.jpg: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: /content/custom_data/data/data/validation/images/crow-644-_jpg.rf.0e2e70266d8e64937e658a921939b0cc.jpg: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: /content/custom_data/data/data/validation/images/crow-645-_jpg.rf.1503e3d28b21833bd9d206dbad84b914.jpg: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: /content/custom_data/data/data/validation/images/crow-649-_jpg.rf.846c21c887a4f987720d19c74cb8ab66.jpg: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: /content/custom_data/data/data/validation/images/crow-65-_jpg.rf.14eeb9ce3bdfebafc8501b862d0bbed8.jpg: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: /content/custom_data/data/data/validation/images/crow-67-_jpg.rf.1d3a91558935dd0972a49fc13b6d783f.jpg: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: /content/custom_data/data/data/validation/images/crow-68-_jpg.rf.a0964c3520ea554a29854e258cf11a8d.jpg: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: /content/custom_data/data/data/validation/images/crow-73-_jpg.rf.d247a70a11eace2162b9d963519348d6.jpg: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: /content/custom_data/data/data/validation/images/crow-83-_jpg.rf.2a3037d22cfe51b4ee7b752bfc373358.jpg: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: /content/custom_data/data/data/validation/images/crow-86-_jpg.rf.8060d8efb390af58dc1cfa6e27be8dda.jpg: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: /content/custom_data/data/data/validation/images/crow-87-_jpg.rf.a93f65033868b2432f5434afceff51d9.jpg: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: /content/custom_data/data/data/validation/images/crow-95-_jpg.rf.24db951fd44c4bad0ad2da53c2ef2bea.jpg: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: /content/custom_data/data/data/validation/images/crow-95-_jpg.rf.993c6b737418b738bd420e1b0fef582e.jpg: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: /content/custom_data/data/data/validation/images/crow-96-_jpg.rf.fd9f77ece025b38883c8cf09f8ee296e.jpg: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: /content/custom_data/data/data/validation/images/crow-97-_jpg.rf.02083cd04dd764a0cfbf43a782d19510.jpg: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: /content/custom_data/data/data/validation/images/crow-99-_jpg.rf.b4a7508e5d175bf0e0d4ae363e7819bd.jpg: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: /content/custom_data/data/data/validation/images/e4379a09-sea51.jpg: ignoring corrupt image/label: Label class 2 exceeds dataset class count 1. Possible class labels are 0-0
# val: /content/custom_data/data/data/validation/images/e9024ff5-sea65.jpg: ignoring corrupt image/label: Label class 2 exceeds dataset class count 1. Possible class labels are 0-0
# Plotting labels to /content/custom_data/data/runs/detect/final_training_v13/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.001429, momentum=0.9) with parameter groups 81 weight(decay=0.0), 88 weight(decay=0.0005), 87 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 2 dataloader workers
# Logging results to /content/custom_data/data/runs/detect/final_training_v13
# Starting training for 6 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#         1/6      1.31G      1.192      2.933      1.614         22        640: 62% ━━━━━━━───── 127/204 19.0it/s 33.1s<4.0s
# Traceback (most recent call last):
#   File "/usr/local/bin/yolo", line 8, in <module>
#     sys.exit(entrypoint())
#              ^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/ultralytics/cfg/__init__.py", line 985, in entrypoint
#     getattr(model, mode)(**overrides)  # default args from model
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/ultralytics/engine/model.py", line 773, in train
#     self.trainer.train()
#   File "/usr/local/lib/python3.12/dist-packages/ultralytics/engine/trainer.py", line 243, in train
#     self._do_train()
#   File "/usr/local/lib/python3.12/dist-packages/ultralytics/engine/trainer.py", line 427, in _do_train
#     loss, self.loss_items = self.model(batch)
#                             ^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1775, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1786, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/ultralytics/nn/tasks.py", line 136, in forward
#     return self.loss(x, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/ultralytics/nn/tasks.py", line 327, in loss
#     preds = self.forward(batch["img"])
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/ultralytics/nn/tasks.py", line 137, in forward
#     return self.predict(x, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/ultralytics/nn/tasks.py", line 154, in predict
#     return self._predict_once(x, profile, visualize, embed)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/ultralytics/nn/tasks.py", line 176, in _predict_once
#     x = m(x)  # run
#         ^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1775, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1786, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/ultralytics/nn/modules/block.py", line 305, in forward
#     y = list(self.cv1(x).chunk(2, 1))
#              ^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1775, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1786, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/ultralytics/nn/modules/conv.py", line 78, in forward
#     return self.act(self.bn(self.conv(x)))
#                     ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1775, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1786, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/batchnorm.py", line 193, in forward
#     return F.batch_norm(
#            ^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/functional.py", line 2813, in batch_norm
#     return torch.batch_norm(
#            ^^^^^^^^^^^^^^^^^
# KeyboardInterrupt

# %%
# !cat /content/data.yaml
# Out:
# path: /content/custom_data/data/data
# train: train/images
# val: validation/images
# nc: 3
# names:
# - pigeon
# - crow
# - seagull

# %% [markdown]
# The model has been trained; now it's time to test it! The commands below run the model on the images in the validation folder and then display the results for the first 10 images. This is a good way to confirm your model is working as expected. Click Play on the blocks below to see how your model performs.

# %%
# !yolo detect predict model=/content/custom_data/data/runs/detect/train7/weights/best.pt source=data/validation/images save=True
# Out:
# Ultralytics 8.3.240 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# YOLO11n summary (fused): 100 layers, 2,582,347 parameters, 0 gradients, 6.3 GFLOPs
#
# image 1/182 /content/custom_data/data/data/validation/images/030_jpg.rf.4ae70b394ba859068f35fa13c853635e.jpg: 640x640 2 birds, 13.5ms
# image 2/182 /content/custom_data/data/data/validation/images/056_jpg.rf.4e107e70488083e32a5b219a61be3589.jpg: 640x640 2 birds, 9.4ms
# image 3/182 /content/custom_data/data/data/validation/images/059_jpg.rf.82145b841efb2063437b33cfef578ecc.jpg: 640x640 2 birds, 8.9ms
# image 4/182 /content/custom_data/data/data/validation/images/0ca47bad-sea77.jpg: 384x640 (no detections), 66.8ms
# image 5/182 /content/custom_data/data/data/validation/images/12-2023-09-07t07-46-59-00-00_cleaned_mp4-0_jpg.rf.1523c9cc77ef2f874fa7ee94bb8fbff4.jpg: 640x640 1 bird, 11.3ms
# image 6/182 /content/custom_data/data/data/validation/images/12-2023-09-07t07-46-59-00-00_cleaned_mp4-3_jpg.rf.7f3f4cc9f2fb0b29010a3bb173be0413.jpg: 640x640 1 bird, 8.7ms
# image 7/182 /content/custom_data/data/data/validation/images/12-2023-09-07t07-47-38-00-00_cleaned_mp4-1_jpg.rf.b9bdcbbb83a38ba35c92418a85645ef3.jpg: 640x640 1 bird, 9.7ms
# image 8/182 /content/custom_data/data/data/validation/images/12-2023-09-07t07-47-38-00-00_cleaned_mp4-3_jpg.rf.caab84fe021ea1d63666a35ddc5b74d5.jpg: 640x640 (no detections), 8.7ms
# image 9/182 /content/custom_data/data/data/validation/images/12-2023-09-11t09-13-14-00-00_cleaned_mp4-4_jpg.rf.df32187832cb4ef9e594f5182e56cf53.jpg: 640x640 (no detections), 8.6ms
# image 10/182 /content/custom_data/data/data/validation/images/120_jpg.rf.4272ab1ef45fa5db548ec7b218210245.jpg: 640x640 2 birds, 8.8ms
# image 11/182 /content/custom_data/data/data/validation/images/4fe30641-sea76.jpg: 544x640 1 bird, 55.2ms
# image 12/182 /content/custom_data/data/data/validation/images/5502ed5f-sea38.jpg: 480x640 1 bird, 56.8ms
# image 13/182 /content/custom_data/data/data/validation/images/69164659-sea31.jpg: 448x640 1 bird, 55.0ms
# image 14/182 /content/custom_data/data/data/validation/images/6f76fe22-sea91.jpg: 480x640 1 bird, 9.9ms
# image 15/182 /content/custom_data/data/data/validation/images/93c5ce56-sea67.jpg: 480x640 (no detections), 8.9ms
# image 16/182 /content/custom_data/data/data/validation/images/Columba-livia139_jpg.rf.7016ad239c2777960a2b0074025f2c1b.jpg: 640x640 1 bird, 9.4ms
# image 17/182 /content/custom_data/data/data/validation/images/Columba-livia157_jpg.rf.3b3488d98d908dff1ee9426e2ce454d2.jpg: 640x640 2 birds, 8.9ms
# image 18/182 /content/custom_data/data/data/validation/images/Columba-livia30_jpg.rf.2b7d7960631397358183d670ede2d170.jpg: 640x640 (no detections), 8.7ms
# image 19/182 /content/custom_data/data/data/validation/images/Columba-livia51_jpg.rf.9328a2a29f82f2475d2aa43d167644b1.jpg: 640x640 1 bird, 8.6ms
# image 20/182 /content/custom_data/data/data/validation/images/Columba-livia66_jpg.rf.88fc65f92799cf7a70f614034e804b77.jpg: 640x640 2 birds, 8.6ms
# image 21/182 /content/custom_data/data/data/validation/images/IMG_4571_JPG_jpg.rf.c3952fce09da9ac41d1326acef83cb3c.jpg: 640x640 5 birds, 8.8ms
# image 22/182 /content/custom_data/data/data/validation/images/IMG_4572_JPG_jpg.rf.721d15aade9e48b5ac0927c4c5241977.jpg: 640x640 5 birds, 8.5ms
# image 23/182 /content/custom_data/data/data/validation/images/IMG_4623_JPG_jpg.rf.07fc7e7a702168af46614f5e06fdff39.jpg: 640x640 1 bird, 8.8ms
# image 24/182 /content/custom_data/data/data/validation/images/IMG_4649_JPG_jpg.rf.480137f227582a4755022f33d69c1336.jpg: 640x640 3 birds, 8.7ms
# image 25/182 /content/custom_data/data/data/validation/images/IMG_4673_JPG_jpg.rf.05036cb34b431ab1c21ffd1ff66d8256.jpg: 640x640 3 birds, 8.9ms
# image 26/182 /content/custom_data/data/data/validation/images/IMG_4687_JPG_jpg.rf.db7f802525d9274e562f5efec213018f.jpg: 640x640 1 bird, 13.4ms
# image 27/182 /content/custom_data/data/data/validation/images/IMG_4689_JPG_jpg.rf.91a3029f6fd3e7666ccb6f24466550e2.jpg: 640x640 2 birds, 11.6ms
# image 28/182 /content/custom_data/data/data/validation/images/IMG_4702_JPG_jpg.rf.1d317da04dcc4d62de54eaa2993c0166.jpg: 640x640 1 bird, 9.1ms
# image 29/182 /content/custom_data/data/data/validation/images/IMG_4763_JPG_jpg.rf.d2c15272f8723ebe8087685af865ae73.jpg: 640x640 2 birds, 8.8ms
# image 30/182 /content/custom_data/data/data/validation/images/Pigeon183_jpg.rf.5ea9f4f0ca6f67f48c1ef4865fae6999.jpg: 640x640 2 birds, 8.8ms
# image 31/182 /content/custom_data/data/data/validation/images/Pigeon86_jpg.rf.4727c96d8fe6a811d0cb1fa13b920504.jpg: 640x640 2 birds, 8.4ms
# image 32/182 /content/custom_data/data/data/validation/images/Rock-Pigeon-118_jpg.rf.a1db09a07225b1c150e880eee133e240.jpg: 640x640 1 bird, 9.7ms
# image 33/182 /content/custom_data/data/data/validation/images/Rock-Pigeon-157_jpg.rf.b27a4cbc534dc4e578d2a34e79720ce6.jpg: 640x640 2 birds, 8.5ms
# image 34/182 /content/custom_data/data/data/validation/images/Rock-Pigeon-174_jpg.rf.f98f8b235bcde94b4935206cfca5087b.jpg: 640x640 1 bird, 8.9ms
# image 35/182 /content/custom_data/data/data/validation/images/Rock-Pigeon-35_jpg.rf.ae65eb5a9f40f6ce4abb2e5a02686b77.jpg: 640x640 1 bird, 8.7ms
# image 36/182 /content/custom_data/data/data/validation/images/a0d641e1-sea66.jpg: 384x640 1 bird, 9.1ms
# image 37/182 /content/custom_data/data/data/validation/images/a683b565-sea92.jpg: 448x640 (no detections), 9.3ms
# image 38/182 /content/custom_data/data/data/validation/images/b59da93c-sea55.jpg: 448x640 (no detections), 8.5ms
# image 39/182 /content/custom_data/data/data/validation/images/c92a38b9-sea73.jpg: 448x640 1 bird, 8.5ms
# image 40/182 /content/custom_data/data/data/validation/images/crow-102-_jpg.rf.a4dd867d7ea746dae05b1312a914ec63.jpg: 640x640 1 bird, 9.5ms
# image 41/182 /content/custom_data/data/data/validation/images/crow-11-_jpg.rf.64fe26e400227822e57994fdb2632e45.jpg: 640x640 (no detections), 9.4ms
# image 42/182 /content/custom_data/data/data/validation/images/crow-121-_jpg.rf.2a89882fbcab8b30494872a9c3cda309.jpg: 640x640 2 birds, 9.1ms
# image 43/182 /content/custom_data/data/data/validation/images/crow-127-_jpg.rf.580bdf3c4186d20ddd9bbad7a2d57812.jpg: 640x640 (no detections), 9.6ms
# image 44/182 /content/custom_data/data/data/validation/images/crow-130-_jpg.rf.3c67814d29d7f2e76b16508724ab4b91.jpg: 640x640 (no detections), 9.1ms
# image 45/182 /content/custom_data/data/data/validation/images/crow-130-_jpg.rf.43167184d238a69d39d71eb10caf104c.jpg: 640x640 (no detections), 11.2ms
# image 46/182 /content/custom_data/data/data/validation/images/crow-135-_jpg.rf.25acb9b84d9f8c6160f1e67413acb46a.jpg: 640x640 1 bird, 9.0ms
# image 47/182 /content/custom_data/data/data/validation/images/crow-138-_jpg.rf.47a1a750cc4a5ceb1965e983dda32b0c.jpg: 640x640 (no detections), 9.1ms
# image 48/182 /content/custom_data/data/data/validation/images/crow-14-_jpg.rf.10097a287a9b15c1ed1bce19af94e677.jpg: 640x640 (no detections), 8.8ms
# image 49/182 /content/custom_data/data/data/validation/images/crow-143-_jpg.rf.ed445b6668b3403e00e030a051a9520c.jpg: 640x640 (no detections), 9.0ms
# image 50/182 /content/custom_data/data/data/validation/images/crow-146-_jpg.rf.85839fdd2f9c4822a4117be35930253b.jpg: 640x640 (no detections), 8.9ms
# image 51/182 /content/custom_data/data/data/validation/images/crow-162-_jpg.rf.6e93669ffc04ff3c57813d8ebcd1f4bf.jpg: 640x640 1 bird, 9.3ms
# image 52/182 /content/custom_data/data/data/validation/images/crow-165-_jpg.rf.a5c9996e4fa4239e0f8a908fc41bb952.jpg: 640x640 (no detections), 9.1ms
# image 53/182 /content/custom_data/data/data/validation/images/crow-168-_jpg.rf.0c37905b998c40d989aff92fd140a70d.jpg: 640x640 (no detections), 9.3ms
# image 54/182 /content/custom_data/data/data/validation/images/crow-176-_jpg.rf.e971c7a93fcc13fb4aee4bd014bad091.jpg: 640x640 (no detections), 9.2ms
# image 55/182 /content/custom_data/data/data/validation/images/crow-177-_jpg.rf.0958cc1fe3130ede05282d8281a1346e.jpg: 640x640 (no detections), 9.1ms
# image 56/182 /content/custom_data/data/data/validation/images/crow-178-_jpg.rf.f4ca6962ca6733243fefe1139e88ff00.jpg: 640x640 (no detections), 8.8ms
# image 57/182 /content/custom_data/data/data/validation/images/crow-179-_jpg.rf.84c83d46accf185e107259b8dccae412.jpg: 640x640 (no detections), 11.6ms
# image 58/182 /content/custom_data/data/data/validation/images/crow-188-_jpg.rf.369d1a2ff90336b7e81df0b6980a13bb.jpg: 640x640 (no detections), 9.0ms
# image 59/182 /content/custom_data/data/data/validation/images/crow-190-_jpg.rf.15712b460c78f86e9a1fb43095fe4ae1.jpg: 640x640 (no detections), 9.0ms
# image 60/182 /content/custom_data/data/data/validation/images/crow-197-_jpg.rf.1e54553f0e73d9ad51ad85079e62990f.jpg: 640x640 (no detections), 9.3ms
# image 61/182 /content/custom_data/data/data/validation/images/crow-206-_jpg.rf.9eaad4982f5cb537c9693decc94fc1d1.jpg: 640x640 (no detections), 15.3ms
# image 62/182 /content/custom_data/data/data/validation/images/crow-208-_jpg.rf.c72d2f386e2c05f30c4af6d5b68af762.jpg: 640x640 (no detections), 15.3ms
# image 63/182 /content/custom_data/data/data/validation/images/crow-212-_jpg.rf.4d35d420007edea2e931c58e5d86cedc.jpg: 640x640 2 birds, 8.8ms
# image 64/182 /content/custom_data/data/data/validation/images/crow-213-_jpg.rf.bd071f9b292e17dc00e0d575c05d6b30.jpg: 640x640 1 bird, 9.0ms
# image 65/182 /content/custom_data/data/data/validation/images/crow-217-_jpg.rf.74c8614c849d418fae4dd2a839dfe14e.jpg: 640x640 1 bird, 8.7ms
# image 66/182 /content/custom_data/data/data/validation/images/crow-219-_jpg.rf.e29eda403079e6dd1db9a3f75eb182ed.jpg: 640x640 (no detections), 9.0ms
# image 67/182 /content/custom_data/data/data/validation/images/crow-22-_jpg.rf.929a82023fe2beef7267f52c80bb6ada.jpg: 640x640 1 bird, 8.9ms
# image 68/182 /content/custom_data/data/data/validation/images/crow-226-_jpg.rf.f4e8e0014ffd6669142e643f5dce93e1.jpg: 640x640 (no detections), 9.0ms
# image 69/182 /content/custom_data/data/data/validation/images/crow-232-_jpg.rf.400bc8d293cbc441ca6ea7e701c7b3ff.jpg: 640x640 (no detections), 8.6ms
# image 70/182 /content/custom_data/data/data/validation/images/crow-233-_jpg.rf.2344854cda74a73fc43ca1a46b97b232.jpg: 640x640 (no detections), 8.7ms
# image 71/182 /content/custom_data/data/data/validation/images/crow-234-_jpg.rf.6b5fe9acef6acf5e4b5af9cbea7c68fa.jpg: 640x640 (no detections), 11.0ms
# image 72/182 /content/custom_data/data/data/validation/images/crow-235-_jpg.rf.b2cd40b7b0eeead4114f7c42645b4539.jpg: 640x640 (no detections), 10.3ms
# image 73/182 /content/custom_data/data/data/validation/images/crow-237-_jpg.rf.b858de8f5abfe85b1fd4e24478c02d46.jpg: 640x640 (no detections), 9.3ms
# image 74/182 /content/custom_data/data/data/validation/images/crow-238-_jpg.rf.4a6825bde22aa8fb66eccc1da7d9299c.jpg: 640x640 (no detections), 9.9ms
# image 75/182 /content/custom_data/data/data/validation/images/crow-249-_jpg.rf.f85ea49838261382d526b47de6525f03.jpg: 640x640 1 bird, 9.3ms
# image 76/182 /content/custom_data/data/data/validation/images/crow-250-_jpg.rf.7c33ce381af767d2ff7ba258a56b6a86.jpg: 640x640 1 bird, 9.0ms
# image 77/182 /content/custom_data/data/data/validation/images/crow-252-_jpg.rf.5a3abd591e70929736da296c29878f36.jpg: 640x640 (no detections), 9.3ms
# image 78/182 /content/custom_data/data/data/validation/images/crow-255-_jpg.rf.53063a5720e8928ea8c0867dd50dde9c.jpg: 640x640 (no detections), 8.9ms
# image 79/182 /content/custom_data/data/data/validation/images/crow-260-_jpg.rf.9338c5a839f37c4939b7491884cafa16.jpg: 640x640 (no detections), 9.2ms
# image 80/182 /content/custom_data/data/data/validation/images/crow-269-_jpg.rf.569020036d5b6aba74d94798acd5f912.jpg: 640x640 (no detections), 8.6ms
# image 81/182 /content/custom_data/data/data/validation/images/crow-275-_jpg.rf.d3407bf81a3885d4d7e070ebb665d8a6.jpg: 640x640 (no detections), 9.1ms
# image 82/182 /content/custom_data/data/data/validation/images/crow-286-_jpg.rf.f4ba9020dddab34aee55dae0216b8242.jpg: 640x640 (no detections), 8.9ms
# image 83/182 /content/custom_data/data/data/validation/images/crow-289-_jpg.rf.9b09019d242765e6133e781fc89c2ef5.jpg: 640x640 2 birds, 8.7ms
# image 84/182 /content/custom_data/data/data/validation/images/crow-29-_jpg.rf.73126467d68591ee819df78780f374dc.jpg: 640x640 (no detections), 8.7ms
# image 85/182 /content/custom_data/data/data/validation/images/crow-298-_jpg.rf.26211ebf80ba12111ec5bffb221ea326.jpg: 640x640 (no detections), 10.4ms
# image 86/182 /content/custom_data/data/data/validation/images/crow-3-_jpg.rf.7604b3b84e0b2379b1408945e5c2d4b0.jpg: 640x640 1 bird, 8.6ms
# image 87/182 /content/custom_data/data/data/validation/images/crow-3-_jpg.rf.b9f633ca061f1d7308da08c0bf1e11d5.jpg: 640x640 (no detections), 9.2ms
# image 88/182 /content/custom_data/data/data/validation/images/crow-306-_jpg.rf.18f7338614644d7f71f65571edd070e7.jpg: 640x640 (no detections), 8.9ms
# image 89/182 /content/custom_data/data/data/validation/images/crow-308-_jpg.rf.3968ce6f48ba483296abf0cc53e7df20.jpg: 640x640 1 bird, 9.3ms
# image 90/182 /content/custom_data/data/data/validation/images/crow-310-_jpg.rf.ef8be79c19ac3025816b156e8d869617.jpg: 640x640 1 bird, 10.6ms
# image 91/182 /content/custom_data/data/data/validation/images/crow-316-_jpg.rf.93a117acaa9f39579aa622a3f1109199.jpg: 640x640 (no detections), 10.2ms
# image 92/182 /content/custom_data/data/data/validation/images/crow-32-_jpg.rf.195655a8995e8351b22504d4fcf13cf4.jpg: 640x640 (no detections), 9.1ms
# image 93/182 /content/custom_data/data/data/validation/images/crow-321-_jpg.rf.f7c85a781a4cbe68e3da3ba4b598bcb1.jpg: 640x640 2 birds, 9.1ms
# image 94/182 /content/custom_data/data/data/validation/images/crow-335-_jpg.rf.afb4b19239e9dcb29414b60807eccba1.jpg: 640x640 3 birds, 9.3ms
# image 95/182 /content/custom_data/data/data/validation/images/crow-343-_jpg.rf.ed7c1e73769847747362113ae427cd69.jpg: 640x640 1 bird, 8.9ms
# image 96/182 /content/custom_data/data/data/validation/images/crow-346-_jpg.rf.13ce979552a2dc5e6bfbf4ad4b820204.jpg: 640x640 (no detections), 9.2ms
# image 97/182 /content/custom_data/data/data/validation/images/crow-348-_jpg.rf.e39d551d16177bc086b6ece735c89334.jpg: 640x640 (no detections), 9.0ms
# image 98/182 /content/custom_data/data/data/validation/images/crow-363-_jpg.rf.b48e0bbb7fab50afef9f0f474f3b83ef.jpg: 640x640 (no detections), 9.0ms
# image 99/182 /content/custom_data/data/data/validation/images/crow-369-_jpg.rf.8340bb55050ace34c5c38aa800cfc45d.jpg: 640x640 1 bird, 8.8ms
# image 100/182 /content/custom_data/data/data/validation/images/crow-374-_jpg.rf.6b6922f0c446694e8eef321986790758.jpg: 640x640 1 bird, 9.3ms
# image 101/182 /content/custom_data/data/data/validation/images/crow-376-_jpg.rf.56e000565202b9c8766bdc21d950c266.jpg: 640x640 2 birds, 9.8ms
# image 102/182 /content/custom_data/data/data/validation/images/crow-376-_jpg.rf.e834658519f1ac721cb0136344008d1a.jpg: 640x640 2 birds, 11.7ms
# image 103/182 /content/custom_data/data/data/validation/images/crow-38-_jpg.rf.7dfb165b0c5b606a6100f146821d8723.jpg: 640x640 (no detections), 9.0ms
# image 104/182 /content/custom_data/data/data/validation/images/crow-384-_jpg.rf.51dd5cadbded0fc50e9721294d7c3651.jpg: 640x640 (no detections), 9.0ms
# image 105/182 /content/custom_data/data/data/validation/images/crow-386-_jpg.rf.596745074706a4c625005b5b06b872c8.jpg: 640x640 (no detections), 9.0ms
# image 106/182 /content/custom_data/data/data/validation/images/crow-390-_jpg.rf.90b2973bd3e6227d903cd9a07dcaa532.jpg: 640x640 (no detections), 9.1ms
# image 107/182 /content/custom_data/data/data/validation/images/crow-397-_jpg.rf.36e7ed9d86287413fa7bc9ab3a20b533.jpg: 640x640 1 bird, 9.0ms
# image 108/182 /content/custom_data/data/data/validation/images/crow-404-_jpg.rf.dea7cb59b04e7482f95487fbf34d6489.jpg: 640x640 1 bird, 9.0ms
# image 109/182 /content/custom_data/data/data/validation/images/crow-409-_jpg.rf.7d3a1baaecbb705ae70a9a369501b8d5.jpg: 640x640 1 bird, 9.2ms
# image 110/182 /content/custom_data/data/data/validation/images/crow-41-_jpg.rf.b51c4fc04c3d195ca534453f6ec162a1.jpg: 640x640 (no detections), 9.0ms
# image 111/182 /content/custom_data/data/data/validation/images/crow-415-_jpg.rf.ce23f9d343a56c899ecba19489a07dae.jpg: 640x640 1 bird, 8.9ms
# image 112/182 /content/custom_data/data/data/validation/images/crow-418-_jpg.rf.a1c5b7ba9c6c4d5ebd52b98c5f1cf8a9.jpg: 640x640 (no detections), 9.0ms
# image 113/182 /content/custom_data/data/data/validation/images/crow-419-_jpg.rf.c66f10a7ac956f53c02e3bf570a5b7c9.jpg: 640x640 1 bird, 13.5ms
# image 114/182 /content/custom_data/data/data/validation/images/crow-425-_jpg.rf.7c7ff23ba967b0c3064ad742467e8feb.jpg: 640x640 (no detections), 9.3ms
# image 115/182 /content/custom_data/data/data/validation/images/crow-427-_jpg.rf.a651fc0b0321f96cec83c96c4c132204.jpg: 640x640 1 bird, 9.0ms
# image 116/182 /content/custom_data/data/data/validation/images/crow-431-_jpg.rf.a858a8dc3ca834b23341ccd10b95bcaf.jpg: 640x640 1 bird, 9.0ms
# image 117/182 /content/custom_data/data/data/validation/images/crow-438-_jpg.rf.93653e9d031af369c371e2d118fa90da.jpg: 640x640 (no detections), 9.3ms
# image 118/182 /content/custom_data/data/data/validation/images/crow-440-_jpg.rf.95940668d6a31586751751aa8024ab82.jpg: 640x640 (no detections), 8.9ms
# image 119/182 /content/custom_data/data/data/validation/images/crow-447-_jpg.rf.55e74f74dbb9c00223748da7acfaff64.jpg: 640x640 (no detections), 15.3ms
# image 120/182 /content/custom_data/data/data/validation/images/crow-448-_jpg.rf.b3b8b3ba185630a13b72076066902d7b.jpg: 640x640 (no detections), 10.7ms
# image 121/182 /content/custom_data/data/data/validation/images/crow-450-_jpg.rf.f6083f134f890e2df26f106128513eef.jpg: 640x640 (no detections), 8.8ms
# image 122/182 /content/custom_data/data/data/validation/images/crow-452-_jpg.rf.412d8ad72b4803d16d9caa65c5f3b70a.jpg: 640x640 (no detections), 8.8ms
# image 123/182 /content/custom_data/data/data/validation/images/crow-459-_jpg.rf.3eb7f5728cc3723dae5a379e04f76700.jpg: 640x640 1 bird, 8.9ms
# image 124/182 /content/custom_data/data/data/validation/images/crow-461-_jpg.rf.c5e341a2c505491b4c873ca4715347ae.jpg: 640x640 (no detections), 9.2ms
# image 125/182 /content/custom_data/data/data/validation/images/crow-48-_jpg.rf.5a2e69c8b9c5ba153e11f37f0c2efc22.jpg: 640x640 1 bird, 9.0ms
# image 126/182 /content/custom_data/data/data/validation/images/crow-489-_jpg.rf.8f9ad7d1261e25b7e3b0196ed2abc635.jpg: 640x640 (no detections), 9.3ms
# image 127/182 /content/custom_data/data/data/validation/images/crow-489-_jpg.rf.997598b76f4dc8e9a4c4d81a5eed1334.jpg: 640x640 1 bird, 9.0ms
# image 128/182 /content/custom_data/data/data/validation/images/crow-49-_jpg.rf.4aa1d1462cefe1557269bd92278ca8f9.jpg: 640x640 (no detections), 8.9ms
# image 129/182 /content/custom_data/data/data/validation/images/crow-491-_jpg.rf.cd9baa53c185f194ece60ab38b8cd2ff.jpg: 640x640 (no detections), 8.7ms
# image 130/182 /content/custom_data/data/data/validation/images/crow-501-_jpg.rf.2f458a9032841b789925a6df15317f80.jpg: 640x640 (no detections), 13.5ms
# image 131/182 /content/custom_data/data/data/validation/images/crow-505-_jpg.rf.db09fcccc182b61b6bc59d29b593f121.jpg: 640x640 (no detections), 12.0ms
# image 132/182 /content/custom_data/data/data/validation/images/crow-51-_jpg.rf.43e914ab7928d2195ca15876b221f3c3.jpg: 640x640 2 birds, 9.0ms
# image 133/182 /content/custom_data/data/data/validation/images/crow-51-_jpg.rf.cdd86822b750f18f1b87b7ce2d172a2f.jpg: 640x640 2 birds, 8.9ms
# image 134/182 /content/custom_data/data/data/validation/images/crow-513-_jpg.rf.01936bc80f17b6a247f0c34f3f9384fe.jpg: 640x640 (no detections), 8.8ms
# image 135/182 /content/custom_data/data/data/validation/images/crow-518-_jpg.rf.7d0df08fd4cb00939992b57436d1aa2b.jpg: 640x640 (no detections), 9.2ms
# image 136/182 /content/custom_data/data/data/validation/images/crow-519-_jpg.rf.ed9338e2c4e59c52781ca027eb5eb2c7.jpg: 640x640 1 bird, 8.9ms
# image 137/182 /content/custom_data/data/data/validation/images/crow-522-_jpg.rf.a8e40c853dd5e6415050ce8b0be08940.jpg: 640x640 (no detections), 9.0ms
# image 138/182 /content/custom_data/data/data/validation/images/crow-529-_jpg.rf.bf2f0485d2ae095a61978d14e3bd7aca.jpg: 640x640 (no detections), 8.9ms
# image 139/182 /content/custom_data/data/data/validation/images/crow-533-_jpg.rf.0834d1356fbaa0778283dff634acd9a0.jpg: 640x640 (no detections), 9.1ms
# image 140/182 /content/custom_data/data/data/validation/images/crow-535-_jpg.rf.77cbef5cc73400eae63b198608c3f8fa.jpg: 640x640 (no detections), 9.1ms
# image 141/182 /content/custom_data/data/data/validation/images/crow-541-_jpg.rf.44c02836a866573513b8c53e3c91d216.jpg: 640x640 1 bird, 10.8ms
# image 142/182 /content/custom_data/data/data/validation/images/crow-55-_jpg.rf.0b5a9c2375540c8d5aef20c997406deb.jpg: 640x640 1 bird, 9.2ms
# image 143/182 /content/custom_data/data/data/validation/images/crow-555-_jpg.rf.3b1d726c499954673fe6e0805886e63b.jpg: 640x640 1 bird, 8.8ms
# image 144/182 /content/custom_data/data/data/validation/images/crow-563-_jpg.rf.9fb78874b11f82dbddc7b3f96496404c.jpg: 640x640 (no detections), 8.8ms
# image 145/182 /content/custom_data/data/data/validation/images/crow-566-_jpg.rf.1492f137676801ac59eeb69629b3753a.jpg: 640x640 1 bird, 8.7ms
# image 146/182 /content/custom_data/data/data/validation/images/crow-568-_jpg.rf.863f98c9e522fb0e4d6a6a4438623dae.jpg: 640x640 1 bird, 10.5ms
# image 147/182 /content/custom_data/data/data/validation/images/crow-569-_jpg.rf.8120f60d94daa8818a3a6c443334a58b.jpg: 640x640 1 bird, 9.0ms
# image 148/182 /content/custom_data/data/data/validation/images/crow-583-_jpg.rf.abe33f82210d939f72d6100f604c4c28.jpg: 640x640 1 bird, 8.6ms
# image 149/182 /content/custom_data/data/data/validation/images/crow-594-_jpg.rf.604d31511f567b06f3925d974425d7a3.jpg: 640x640 1 bird, 8.7ms
# image 150/182 /content/custom_data/data/data/validation/images/crow-598-_jpg.rf.81adc0f48445037a0781a59a2af75aa4.jpg: 640x640 (no detections), 9.4ms
# image 151/182 /content/custom_data/data/data/validation/images/crow-6-_jpg.rf.80248fb358241268cb49d037484818dd.jpg: 640x640 (no detections), 8.7ms
# image 152/182 /content/custom_data/data/data/validation/images/crow-603-_jpg.rf.7c90210e4d2b5e890b81636d8caf434a.jpg: 640x640 1 bird, 8.6ms
# image 153/182 /content/custom_data/data/data/validation/images/crow-605-_jpg.rf.63ddd46e01eef006a0e3b4c5b0b3f712.jpg: 640x640 (no detections), 8.9ms
# image 154/182 /content/custom_data/data/data/validation/images/crow-609-_jpg.rf.43c85e029557eb1b143d82232bd1b387.jpg: 640x640 (no detections), 8.9ms
# image 155/182 /content/custom_data/data/data/validation/images/crow-612-_jpg.rf.1054d2422fdffeee15bd19a0a3ef957a.jpg: 640x640 (no detections), 9.8ms
# image 156/182 /content/custom_data/data/data/validation/images/crow-612-_jpg.rf.354fc14936adfe4074d9a7f1d885afc6.jpg: 640x640 1 bird, 9.3ms
# image 157/182 /content/custom_data/data/data/validation/images/crow-613-_jpg.rf.c08fb377c4ed4433d4b0417fdbd8e193.jpg: 640x640 (no detections), 9.1ms
# image 158/182 /content/custom_data/data/data/validation/images/crow-614-_jpg.rf.c5a9ee715c0e049d6ecfa961af3ac188.jpg: 640x640 (no detections), 8.7ms
# image 159/182 /content/custom_data/data/data/validation/images/crow-617-_jpg.rf.a8aef9c1c28fa6b158031554717a79e1.jpg: 640x640 1 bird, 9.4ms
# image 160/182 /content/custom_data/data/data/validation/images/crow-632-_jpg.rf.de0b4453de640f790103509bfe28c01d.jpg: 640x640 1 bird, 11.7ms
# image 161/182 /content/custom_data/data/data/validation/images/crow-637-_jpg.rf.bfdd01b8cab4bba492d824c6bef9393c.jpg: 640x640 1 bird, 8.9ms
# image 162/182 /content/custom_data/data/data/validation/images/crow-638-_jpg.rf.f75e350fe4ed4fa851248bcc9ebd463e.jpg: 640x640 1 bird, 8.9ms
# image 163/182 /content/custom_data/data/data/validation/images/crow-64-_jpg.rf.e9ce9349f7662d9b234de785a7a65263.jpg: 640x640 (no detections), 8.9ms
# image 164/182 /content/custom_data/data/data/validation/images/crow-642-_jpg.rf.ea043e21db0f4419a5b3999911bcb317.jpg: 640x640 (no detections), 9.2ms
# image 165/182 /content/custom_data/data/data/validation/images/crow-644-_jpg.rf.0e2e70266d8e64937e658a921939b0cc.jpg: 640x640 (no detections), 8.7ms
# image 166/182 /content/custom_data/data/data/validation/images/crow-645-_jpg.rf.1503e3d28b21833bd9d206dbad84b914.jpg: 640x640 (no detections), 8.9ms
# image 167/182 /content/custom_data/data/data/validation/images/crow-649-_jpg.rf.846c21c887a4f987720d19c74cb8ab66.jpg: 640x640 (no detections), 9.3ms
# image 168/182 /content/custom_data/data/data/validation/images/crow-65-_jpg.rf.14eeb9ce3bdfebafc8501b862d0bbed8.jpg: 640x640 (no detections), 8.8ms
# image 169/182 /content/custom_data/data/data/validation/images/crow-67-_jpg.rf.1d3a91558935dd0972a49fc13b6d783f.jpg: 640x640 (no detections), 9.0ms
# image 170/182 /content/custom_data/data/data/validation/images/crow-68-_jpg.rf.a0964c3520ea554a29854e258cf11a8d.jpg: 640x640 (no detections), 9.4ms
# image 171/182 /content/custom_data/data/data/validation/images/crow-73-_jpg.rf.d247a70a11eace2162b9d963519348d6.jpg: 640x640 (no detections), 9.1ms
# image 172/182 /content/custom_data/data/data/validation/images/crow-83-_jpg.rf.2a3037d22cfe51b4ee7b752bfc373358.jpg: 640x640 (no detections), 8.7ms
# image 173/182 /content/custom_data/data/data/validation/images/crow-86-_jpg.rf.8060d8efb390af58dc1cfa6e27be8dda.jpg: 640x640 (no detections), 9.0ms
# image 174/182 /content/custom_data/data/data/validation/images/crow-87-_jpg.rf.a93f65033868b2432f5434afceff51d9.jpg: 640x640 1 bird, 8.8ms
# image 175/182 /content/custom_data/data/data/validation/images/crow-95-_jpg.rf.24db951fd44c4bad0ad2da53c2ef2bea.jpg: 640x640 (no detections), 9.0ms
# image 176/182 /content/custom_data/data/data/validation/images/crow-95-_jpg.rf.993c6b737418b738bd420e1b0fef582e.jpg: 640x640 (no detections), 12.7ms
# image 177/182 /content/custom_data/data/data/validation/images/crow-96-_jpg.rf.fd9f77ece025b38883c8cf09f8ee296e.jpg: 640x640 (no detections), 9.1ms
# image 178/182 /content/custom_data/data/data/validation/images/crow-97-_jpg.rf.02083cd04dd764a0cfbf43a782d19510.jpg: 640x640 (no detections), 15.1ms
# image 179/182 /content/custom_data/data/data/validation/images/crow-99-_jpg.rf.b4a7508e5d175bf0e0d4ae363e7819bd.jpg: 640x640 (no detections), 11.5ms
# image 180/182 /content/custom_data/data/data/validation/images/e4379a09-sea51.jpg: 416x640 1 bird, 56.3ms
# image 181/182 /content/custom_data/data/data/validation/images/e9024ff5-sea65.jpg: 448x640 (no detections), 11.7ms
# image 182/182 /content/custom_data/data/data/validation/images/feralpigeon51_jpg.rf.02c618391031cf946e50bca3a68f906f.jpg: 640x640 2 birds, 9.6ms
# Speed: 1.9ms preprocess, 10.8ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to /content/custom_data/data/runs/detect/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
import glob
from IPython.display import Image, display
for image_path in glob.glob(f'/content/custom_data/data/runs/detect/predict/*.jpg')[:10]:
  display(Image(filename=image_path, height=400))
  print('\n')

# %% [markdown]
# The model should draw a box around each object of interest in each image. If it isn't doing a good job of detecting objects, here are a few tips:
#
# 1. Double-check your dataset to make sure there are no labeling errors or conflicting examples.
# 2. Increase the number of epochs used for training.
# 3. Use a larger model size (e.g. `yolo11l.pt`).
# 4. Add more images to the training dataset. See my [dataset video](https://www.youtube.com/watch?v=v0ssiOY6cfg) for tips on how to capture good training images and improve accuracy.
#
# You can also run the model on video files or other images images by uploading them to this notebook and using the above `!yolo detect predict` command, where `source` points to the location of the video file, image, or folder of images. The results will be saved in `runs/detect/predict`.
#
# Drawing boxes on images is great, but it isn't very useful in itself. It's also not very helpful to just run this models inside a Colab notebook: it's easier if we can just run it on a local computer. Continue to the next section to see how to download your newly trained model and run it on a local device.

# %% [markdown]
# #7.&nbsp;Deploy Model

# %% [markdown]
# Now that your custom model has been trained, it's ready to be downloaded and deployed in an application! YOLO models can run on a wide variety of hardware, including PCs, embedded systems, and phones. Ultralytics makes it easy to convert the YOLO models to various formats (`tflite`, `onnx`, etc.) and deploy them in a variety of environments.
#
# This section shows how to download the model and provides links to instructions for deploying it on your PC and edge devices like the Raspberry Pi.

# %% [markdown]
# ## 7.1 Download YOLO Model
#
# First, zip and download the trained model by running the code blocks below.
#
# The code creates a folder named `my_model`, moves the model weights into it, and renames them from `best.pt` to `my_model.pt`. It also adds the training results in case you want to reference them later. It then zips the folder as `my_model.zip`.

# %%
# Create "my_model" folder to store model weights and train results
# !mkdir /content/my_model
# !cp /content/runs/detect/train/weights/best.pt /content/my_model/my_model.pt
# !cp -r /content/runs/detect/train /content/my_model

# Zip into "my_model.zip"
# %cd my_model
# !zip /content/my_model.zip my_model.pt
# !zip -r /content/my_model.zip train
# %cd /content

# %%
# This takes forever for some reason, you can also just download the model from the sidebar
from google.colab import files

files.download('/content/my_model.zip')

# %% [markdown]
# ## 7.2 Deploy YOLO Model on Local Devices
#
# Next, we'll take our downloaded model and run it on a local device. This section provides instructions showing how to deploy YOLO models on various devices.
#
# I wrote a basic Python script, `yolo_detect.py`, that shows how to load a model, run inference on an image source, parse the inference results, and display boxes around each detected class in the image. The [script](https://github.com/EdjeElectronics/Train-and-Deploy-YOLO-Models/blob/main/yolo_detect.py) gives an example of how to work with Ultralytics YOLO models in Python, and it can be used as a starting point for more advanced applications.

# %% [markdown]
# ### 7.2.1 Deploy on PC (Windows, Linux, or macOS)
#
# The easiest way to run Ultralytics models on a PC is using Anaconda. Anaconda sets up a virtual Python environment and allows you to easily install Ultralytics and PyTorch. It automatically installs CUDA and cuDNN, which allows you to speed up model inference with your NVIDIA GPU.
#
# > **NOTE:** My YouTube video (link to be added) shows how to deploy your model on a PC. It walks through the following steps, so watch the video if you prefer having visual instructions.
#
# **1. Download and Install Anaconda**
#
# Go to the Anaconda download page at https://anaconda.com/download, click the “skip registration” button, and then download the package for your OS. When it's finished downloading, run the installer and click through the installation steps. You can use the default options for installation.
#
# **2. Set up virtual environment**
#
# Once it's installed, run Anaconda Prompt from the Start Bar. (If you're on macOS or Linux, just open a command terminal).
#
# Issue the following commands to create a new Python environment and activate it:
#
# ```
# conda create --name yolo-env1 python=3.12 -y
# conda activate yolo-env1
# ```
#
# Install Ultralytics (which also installs import libraries like OpenCV-Python, Numpy, and PyTorch) by issuing the following command:
#
# ```
# pip install ultralytics
# ```
#
# If you have an NVIDIA GPU, you can install the GPU-enabled version of PyTorch by issuing the following command:
#
# ```
# pip install --upgrade torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu124
# ```
#
# **3. Extract downloaded model**
# Take the `my_model.zip` file you downloaded in Step 7.1 and unzip it to a folder on your PC. In the Anaconda Prompt terminal, move into the unzipped folder using:
#
# ```
# cd path/to/folder
# ```
#
# **4. Download and run yolo_detect.py**
#
# Download the `yolo_detect.py` script into the `my_model` folder using:
#
# ```
# curl -o yolo_detect.py https://raw.githubusercontent.com/EdjeElectronics/Train-and-Deploy-YOLO-Models/refs/heads/main/yolo_detect.py
# ```
#
# Alright! We're ready to run the script. To run inference with a yolov8s model on a USB camera at 1280x720 resolution, issue:
#
# ```
# python yolo_detect.py --model my_model.pt --source usb0 --resolution 1280x720
# ```
#
# A window will appear showing a live feed from your webcam with boxes drawn around detected objects in each frame.
#
# You can also run the model on an video file, image, or folder of images. To see a full list of arguments for `yolo_detect.py`, issue `python yolo_detect.py --help` or see the [README file](https://github.com/EdjeElectronics/Train-and-Deploy-YOLO-Models/blob/main/README.md).

# %% [markdown]
# ### 7.2.2 Deploy on Raspberry Pi
#
# Keep an eye out for an article showing how to convert YOLO models to NCNN format and run them on the Raspberry Pi!

# %% [markdown]
# # 8.&nbsp;Conclusion

# %% [markdown]
# Congratulations! You've successfully trained and deployed a YOLO object detection model. 😀
#
# Next, you can extend your application beyond just drawing boxes and counting objects. Add functionality like logging the number of objects detected over time or taking a picture when certain objects are detected. Check out some example applications at our GitHub repository: https://github.com/EdjeElectronics/Train-and-Deploy-YOLO-Models
#
# Thanks for working through this notebook, and good luck with your projects!

# %% [markdown]
# # Appendix: Common Errors

# %% [markdown]
# If you run into any errors working through this notebook, please do the following:
#
#
# - Double-check that the dataset files are set up in the correct folder structure
# - Make sure there are no typos or errors in your labelmap file
# - Google search the error to look for solutions
#
# If none of those help, please submit an [Issue](https://github.com/EdjeElectronics/Train-and-Deploy-YOLO-Models/issues) on the GitHub page. In this section, I will add resolutions to common errors as they come up.
